# %% [markdown]
# # DataFrames 2: Filtering Data

# %%
import pandas as pd
import datetime as dt

# %% [markdown]
# ## This Module's Dataset + Memory Optimization
# - `pd.to_datetime` method converts a **Series** to hold datetime values.
# - the `format` param informs pandas of the fomat that the times are stored in
# - We pass symbols designating the segments of the string. For example, %m means "month" and %d means day
# - the `dt` attribute reveals an object with many datetime-related attributes and methods.
# - the `dt.time` attribute extracts only the time from each value in a datetime **Series**
# - the `parsedate` param of `read_csv` alt way to parse strings as datetime

# %%
employees_df = pd.read_csv("employees.csv")

# %%
employees = employees_df.copy()
employees
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [1000 rows x 8 columns]

# %%
employees['Start Date'] = pd.to_datetime(employees['Start Date'], format="%m/%d/%Y")

# %%
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%I:%M %p").dt.time

# %%
employees
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        16:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [1000 rows x 8 columns]

# %%
employees["Senior Management"] = employees["Senior Management"].astype(bool)

# %%
employees["Gender"] = employees["Gender"].astype("category")

# %%
employees
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        16:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 49.1+ KB

# %%
# Reimport original knowing our optimizations... this can get copied later
employees_df = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y") # Do in csv
employees_df["Last Login Time"] = pd.to_datetime(employees_df["Last Login Time"], format="%I:%M %p").dt.time
employees_df["Senior Management"] = employees_df["Senior Management"].astype(bool)
employees_df["Gender"] = employees_df["Gender"].astype("category")

# %% [markdown]
# ## Filter A DataFrame Based On A Condition
# - Pandas needs **Series** of Booleans to perform a filter
# - Pass the boolean Series inside square bracks after df

# %%
employees = employees_df.copy()

# %%
employees["Gender"] == "Male"
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
employees[employees["Gender"] == "Male"]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31        06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04        13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24        16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18        01:35:00  115163   10.125
# ..         ...    ...        ...             ...     ...      ...
# 994     George   Male 2013-06-21        17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20        16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15        18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [424 rows x 8 columns]

# %%
employees[(employees["Gender"] == "Female") & employees["Senior Management"]]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 6         Ruby  Female 1987-08-17        16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20        10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22        06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08        06:51:00  139852    7.524
# 10      Louise  Female 1980-08-12        09:01:00   63241   15.132
# ..         ...     ...        ...             ...     ...      ...
# 982       Rose  Female 1982-04-06        10:43:00   91411    8.639
# 987     Gloria  Female 2014-12-08        05:08:00  136709   10.331
# 990      Robin  Female 1987-07-24        13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25        05:12:00  134505   11.051
# 993       Tina  Female 1997-05-15        15:53:00   56450   19.040
#
#      Senior Management                  Team
# 6                 True               Product
# 7                 True               Finance
# 8                 True           Engineering
# 9                 True  Business Development
# 10                True                   NaN
# ..                 ...                   ...
# 982               True       Human Resources
# 987               True               Finance
# 990               True       Client Services
# 991               True             Marketing
# 993               True           Engineering
#
# [231 rows x 8 columns]

# %%
employees[(employees["Salary"] > 140000) & (~(employees["Senior Management"]))]
# Out:
#      First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 36       Rachel  Female 2009-02-16        20:47:00  142032   12.599
# 96      Cynthia  Female 1994-03-21        08:34:00  142321    1.737
# 110     Shirley  Female 2001-06-20        22:39:00  147113   16.135
# 132      Carlos    Male 1995-01-04        07:02:00  146670   10.763
# 142   Elizabeth  Female 2003-10-09        17:53:00  146129    5.687
# 178        Jane  Female 1997-09-03        02:01:00  144474   17.648
# 208    Jonathan    Male 1987-10-12        02:59:00  141069    4.903
# 216     Matthew    Male 2013-07-31        08:04:00  142373    2.462
# 232     Marilyn  Female 1997-04-04        21:28:00  147663   10.263
# 244    Clarence    Male 1996-10-08        12:53:00  142561    8.866
# 284      Brenda  Female 2005-10-06        21:33:00  141521    4.337
# 318         Roy    Male 2006-08-06        07:52:00  148225    1.841
# 319  Jacqueline  Female 1981-11-25        15:01:00  145988   18.243
# 349     Phyllis  Female 2005-11-24        23:57:00  140347    8.723
# 365      Gloria     NaN 1983-07-19        01:57:00  140885    1.113
# 368     Marilyn  Female 1982-12-17        12:10:00  147183    8.748
# 370       Linda  Female 2009-07-15        22:12:00  144001    2.194
# 429        Rose  Female 2015-05-28        08:40:00  149903    5.630
# 471      Sharon  Female 2002-03-12        06:32:00  147635   14.693
# 476       Kathy  Female 1996-10-25        12:59:00  143541    8.461
# 510       Frank    Male 2003-04-27        12:04:00  140303   17.070
# 526     Barbara  Female 2004-03-22        08:11:00  144677    8.696
# 644   Katherine  Female 1996-08-13        00:21:00  149908   18.912
# 740     Russell     NaN 2009-05-09        11:59:00  149456    3.533
# 750       Louis     NaN 1983-02-05        18:39:00  145274   16.379
# 797        Rose  Female 1982-12-31        18:50:00  145001   19.850
# 800    Clarence    Male 1989-08-05        18:11:00  148941   11.517
# 808       Julie  Female 1980-03-08        05:13:00  145357    3.459
# 828     Cynthia  Female 2006-07-12        08:55:00  149684    7.864
# 844       Maria     NaN 1985-06-19        01:48:00  148857    8.738
# 850     Charles    Male 1997-09-03        10:04:00  148291    6.002
# 861       Jerry    Male 1989-03-26        04:15:00  140850   18.855
# 881        Ruby  Female 1980-01-28        23:08:00  142868    6.318
# 931      Harold    Male 2012-06-23        12:40:00  140444    3.771
# 933       Doris  Female 1993-07-05        17:54:00  141439    3.799
# 981       James    Male 1993-01-15        17:19:00  148985   19.280
# 983        John    Male 1982-12-23        22:35:00  146907   11.738
#
#      Senior Management                  Team
# 36               False  Business Development
# 96               False               Finance
# 110              False                 Legal
# 132              False       Human Resources
# 142              False               Finance
# 178              False               Product
# 208              False       Human Resources
# 216              False             Marketing
# 232              False       Human Resources
# 244              False       Client Services
# 284              False       Client Services
# 318              False               Finance
# 319              False             Marketing
# 349              False                 Sales
# 365              False       Human Resources
# 368              False  Business Development
# 370              False  Business Development
# 429              False       Human Resources
# 471              False       Human Resources
# 476              False       Human Resources
# 510              False                 Legal
# 526              False               Finance
# 644              False               Finance
# 740              False             Marketing
# 750              False               Product
# 797              False           Engineering
# 800              False               Product
# 808              False           Engineering
# 828              False               Product
# 844              False                 Legal
# 850              False                   NaN
# 861              False               Finance
# 881              False             Marketing
# 931              False          Distribution
# 933              False  Business Development
# 981              False                 Legal
# 983              False           Engineering

# %% [markdown]
# employees.info()

# %%
employees[employees["Start Date"] > "2010-01-01"]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 7          NaN  Female 2015-07-20        10:43:00   45906   11.598
# 15     Lillian  Female 2016-06-05        06:09:00   59414    1.256
# 16      Jeremy    Male 2010-09-21        05:56:00   90370    7.369
# 19       Donna  Female 2010-07-22        03:48:00   81014    1.894
# 22      Joshua     NaN 2012-03-08        01:58:00   90816   18.816
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male 2013-06-21        17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        18:24:00  129949   10.169
#
#      Senior Management                  Team
# 7                 True               Finance
# 15               False               Product
# 16               False       Human Resources
# 19               False               Product
# 22                True       Client Services
# ..                 ...                   ...
# 994               True             Marketing
# 995              False          Distribution
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [180 rows x 8 columns]

# %%
employees[employees["Start Date"] > dt.datetime(2010, 1, 1)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 7          NaN  Female 2015-07-20        10:43:00   45906   11.598
# 15     Lillian  Female 2016-06-05        06:09:00   59414    1.256
# 16      Jeremy    Male 2010-09-21        05:56:00   90370    7.369
# 19       Donna  Female 2010-07-22        03:48:00   81014    1.894
# 22      Joshua     NaN 2012-03-08        01:58:00   90816   18.816
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male 2013-06-21        17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        18:24:00  129949   10.169
#
#      Senior Management                  Team
# 7                 True               Finance
# 15               False               Product
# 16               False       Human Resources
# 19               False               Product
# 22                True       Client Services
# ..                 ...                   ...
# 994               True             Marketing
# 995              False          Distribution
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [180 rows x 8 columns]

# %%
employees[employees["Last Login Time"] < dt.time(12, 0)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 7          NaN  Female 2015-07-20        10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22        06:29:00   95570   18.523
# ..         ...     ...        ...             ...     ...      ...
# 988      Alice  Female 2004-10-05        09:34:00   47638   11.209
# 991       Rose  Female 2002-08-25        05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
#
#      Senior Management             Team
# 1                 True              NaN
# 2                False          Finance
# 5                False            Legal
# 7                 True          Finance
# 8                 True      Engineering
# ..                 ...              ...
# 988              False  Human Resources
# 991               True        Marketing
# 992               True          Finance
# 995              False     Distribution
# 996              False          Finance
#
# [496 rows x 8 columns]

# %% [markdown]
# ## The isin Method
# - The `isin` Series method accepts an iterable object
# - The method returns true if it's value is found in the collection

# %%
employees = employees_df.copy()

# %%
employees[employees["Team"].isin({'Legal', 'Product', 'Sales'})] # Param can be list, set, series... etc
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17        16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26        15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27        23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05        06:09:00   59414    1.256
# ..         ...     ...        ...             ...     ...      ...
# 981      James    Male 1993-01-15        17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10        20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10        16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15        18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]

# %% [markdown]
# ## The isnull and notnull Methods
# - The `isnull` method returns True fo `NaN` values in **Series**
# - Vice versaa `notnull`

# %%
employees[employees["Gender"].isnull()]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 20        Lois    NaN 1995-04-22        19:18:00   64714    4.934
# 22      Joshua    NaN 2012-03-08        01:58:00   90816   18.816
# 27       Scott    NaN 1991-07-11        18:58:00  122367    5.218
# 31       Joyce    NaN 2005-02-20        14:40:00   88657   12.752
# 41   Christine    NaN 2015-06-28        01:08:00   66582   11.308
# ..         ...    ...        ...             ...     ...      ...
# 961    Antonio    NaN 1989-06-18        21:37:00  103050    3.050
# 972     Victor    NaN 2006-07-28        14:49:00   76381   11.159
# 985    Stephen    NaN 1983-07-10        20:10:00   85668    1.909
# 989     Justin    NaN 1991-02-10        16:58:00   38344    3.794
# 995      Henry    NaN 2014-11-23        06:09:00  132483   16.655
#
#      Senior Management                  Team
# 20                True                 Legal
# 22                True       Client Services
# 27               False                 Legal
# 31               False               Product
# 41                True  Business Development
# ..                 ...                   ...
# 961              False                 Legal
# 972               True                 Sales
# 985              False                 Legal
# 989              False                 Legal
# 995              False          Distribution
#
# [145 rows x 8 columns]

# %%
employees[employees["Gender"].notnull()]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        16:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male 2013-06-21        17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [855 rows x 8 columns]

# %% [markdown]
# ## The between Method
# - The between method returns True if a **Series** value is found within its range.

# %%
employees = employees_df.copy()

# %%
employees[employees["Salary"].between(100000, 110000)] # inclusive
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 4        Larry    Male 1998-01-24        16:47:00  101004    1.389
# 11       Julie  Female 1997-10-26        15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27        23:40:00  109831    5.831
# 21     Matthew    Male 1995-09-05        02:12:00  100612   13.645
# 55       Karen  Female 1999-11-30        07:46:00  102488   17.653
# ..         ...     ...        ...             ...     ...      ...
# 944    Kenneth    Male 2006-05-10        08:24:00  101914    1.905
# 947        NaN    Male 2012-07-30        15:07:00  107351    5.329
# 961    Antonio     NaN 1989-06-18        21:37:00  103050    3.050
# 967     Thomas    Male 2016-03-12        15:10:00  105681   19.572
# 990      Robin  Female 1987-07-24        13:35:00  100765   10.982
#
#      Senior Management             Team
# 4                 True  Client Services
# 11                True            Legal
# 13               False            Sales
# 21               False        Marketing
# 55                True          Product
# ..                 ...              ...
# 944               True     Distribution
# 947               True        Marketing
# 961              False            Legal
# 967              False      Engineering
# 990               True  Client Services
#
# [87 rows x 8 columns]

# %% [markdown]
# ## The duplicated Method
# - The `duplicated` method returns True if a series value is a duplicate
# - Pandas will mark one occurence of a repeated value as a non-duplicate.
# - Use the `keep` parameter to designate whether the first or last occurence of a repeated value should be considered the "non-duplicate"
# - Pass False to the keep parmeter to mark all occurences of repeated values as duplicates

# %%
employees = employees_df.copy()

# %%
employees[employees.duplicated()]
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
employees[~(employees["First Name"].duplicated(keep="first"))] # unique first names, keep of false will say keep no values with dupes
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        16:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 712     Martin     NaN 2001-02-06        04:17:00  123963   15.745
# 749      Janet     NaN 1986-01-25        05:48:00   85789    9.712
# 832      Keith    Male 2003-02-12        15:02:00  120672   19.467
# 855    Phillip     NaN 2003-10-20        11:09:00   89700    2.277
# 887      David    Male 2009-12-05        08:48:00   92242   15.407
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 2                False          Finance
# 3                 True          Finance
# 4                 True  Client Services
# ..                 ...              ...
# 712               True      Engineering
# 749              False            Legal
# 832              False            Legal
# 855               True              NaN
# 887              False            Legal
#
# [201 rows x 8 columns]

# %% [markdown]
# ## The drop_duplicates Method

# %%
employees=employees_df.copy()

# %%
employees.drop_duplicates()
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        16:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
employees.drop_duplicates("Team") # Non mutating
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1      Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2       Maria  Female 1993-04-23        11:17:00  130590   11.858
# 4       Larry    Male 1998-01-24        16:47:00  101004    1.389
# 5      Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17        16:20:00   65476   10.012
# 8      Angela  Female 2005-11-22        06:29:00   95570   18.523
# 9     Frances  Female 2002-08-08        06:51:00  139852    7.524
# 12    Brandon    Male 1980-12-01        01:08:00  112807   17.492
# 13       Gary    Male 2008-01-27        23:40:00  109831    5.831
# 40    Michael    Male 2008-10-10        11:25:00   99283    2.665
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 4                True       Client Services
# 5               False                 Legal
# 6                True               Product
# 8                True           Engineering
# 9                True  Business Development
# 12               True       Human Resources
# 13              False                 Sales
# 40               True          Distribution

# %%
employees.drop_duplicates("First Name", keep=False)
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 8       Angela  Female 2005-11-22        06:29:00   95570   18.523
# 33        Jean  Female 1993-12-18        09:07:00  119082   16.180
# 190      Carol  Female 1996-03-19        03:39:00   57783    9.129
# 291      Tammy  Female 1984-11-11        10:30:00  132839   17.463
# 495     Eugene    Male 1984-05-24        10:54:00   81077    2.117
# 688      Brian    Male 2007-04-07        22:47:00   93901   17.821
# 832      Keith    Male 2003-02-12        15:02:00  120672   19.467
# 887      David    Male 2009-12-05        08:48:00   92242   15.407
#
#      Senior Management                  Team
# 5                False                 Legal
# 8                 True           Engineering
# 33               False  Business Development
# 190              False               Finance
# 291               True       Client Services
# 495              False                 Sales
# 688               True                 Legal
# 832              False                 Legal
# 887              False                 Legal

# %%
employees.drop_duplicates(["Senior Management", "Team"]).sort_values("Team")
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 33       Jean  Female 1993-12-18        09:07:00  119082   16.180
# 9     Frances  Female 2002-08-08        06:51:00  139852    7.524
# 4       Larry    Male 1998-01-24        16:47:00  101004    1.389
# 18      Diana  Female 1981-10-23        10:27:00  132940   19.082
# 60      Paula     NaN 2005-11-23        14:01:00   48866    4.271
# 40    Michael    Male 2008-10-10        11:25:00   99283    2.665
# 8      Angela  Female 2005-11-22        06:29:00   95570   18.523
# 54       Sara  Female 2007-08-15        09:23:00   83677    8.999
# 2       Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04        13:00:00  138705    9.340
# 16     Jeremy    Male 2010-09-21        05:56:00   90370    7.369
# 12    Brandon    Male 1980-12-01        01:08:00  112807   17.492
# 11      Julie  Female 1997-10-26        15:19:00  102508   12.637
# 5      Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 21    Matthew    Male 1995-09-05        02:12:00  100612   13.645
# 0     Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 6        Ruby  Female 1987-08-17        16:20:00   65476   10.012
# 15    Lillian  Female 2016-06-05        06:09:00   59414    1.256
# 13       Gary    Male 2008-01-27        23:40:00  109831    5.831
# 45      Roger    Male 1980-04-17        11:32:00   88010   13.886
# 1      Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 91      James     NaN 2005-01-26        23:00:00  128771    8.309
#
#     Senior Management                  Team
# 33              False  Business Development
# 9                True  Business Development
# 4                True       Client Services
# 18              False       Client Services
# 60              False          Distribution
# 40               True          Distribution
# 8                True           Engineering
# 54              False           Engineering
# 2               False               Finance
# 3                True               Finance
# 16              False       Human Resources
# 12               True       Human Resources
# 11               True                 Legal
# 5               False                 Legal
# 21              False             Marketing
# 0                True             Marketing
# 6                True               Product
# 15              False               Product
# 13              False                 Sales
# 45               True                 Sales
# 1                True                   NaN
# 91              False                   NaN

# %% [markdown]
# ## The unique and nunique Methods

# %%
employees = employees_df.copy()

# %%
employees["Gender"].unique()
# Out:
# ['Male', 'Female', NaN]
# Categories (2, object): ['Female', 'Male']

# %%
employees["Gender"].nunique()
# Out:
# 2

# %%
type(employees["Gender"].unique())# categories unique gets type that is in pandas
# Out:
# pandas.core.arrays.categorical.Categorical

# %%
type(employees["First Name"].unique())
# Out:
# numpy.ndarray

# %%
employees["Gender"].nunique(dropna=False) # NaN will be counted as a unique val
# Out:
# 3

# %%
employees.nunique()
# Out:
# First Name           200
# Gender                 2
# Start Date           972
# Last Login Time      720
# Salary               995
# Bonus %              971
# Senior Management      2
# Team                  10
# dtype: int64
